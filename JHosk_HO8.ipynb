# %% [markdown]
# # Strings
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 10.1 Email Creator
# Create a program that reads a file and creates a series of emails.
#
# ### Console:
# ```powershell
# Email Creator
#
# ================================================================
# To: jbutler@gmail.com
# From: noreply@deals.com
# Subject: Deals!
#
# Hi James,
#
# We've got some great deals for you. Check our website!
# ================================================================
# To:	josephine_darakjy@darakjy.org
# From:	noreply@deals.com
# Subject: Deals!
#
# Hi Josephine,
#
# We've got some great deals for you. Check our website!
# ================================================================
# To:	art@venere.org
# From:	noreply@deals.com
# Subject: Deals!
#
# Hi Art,
#
# We've got some great deals for you. Check our website!
# ```
#
# ### Specifications:
# - Use `email.csv` file:
# - Use `email_template.txt` file:
# - When the program starts, it should read the email addresses and first names from the file, merge them into the mass email template, and display the results on the console.
# - All email addresses should be converted to **lowercase**.
# - All first names should be converted to **title case**.
# - If you add names to the list of email addresses, the program should create more emails.
# - If you modify the template, the program should change the content of the email that’s created.

# %%
### CODE HERE ###
import csv

# Function to read the email addresses and first names from the CSV file
def read_email_list(file_name):
    email_list = []
    try:
        with open(file_name, 'r') as file:
            reader = csv.reader(file)
            for row in reader:
                email_list.append((row[0].strip().lower(), row[1].strip().title()))  # Convert email to lowercase, name to title case
    except FileNotFoundError:
        print(f"Error: The file '{file_name}' was not found.")
    return email_list

# Function to read the email template from the text file
def read_template(file_name):
    try:
        with open(file_name, 'r') as file:
            template = file.read()
    except FileNotFoundError:
        print(f"Error: The file '{file_name}' was not found.")
        template = ""
    return template

# Function to create and display emails from the email list and template
def create_emails(email_list, template):
    if not email_list or not template:
        print("Error: Missing email list or template.")
        return

    for email, first_name in email_list:
        email_content = template.format(email=email+'@gmail.com', first_name=first_name)
        print("="*64)
        print(email_content)
        print("="*64)

# Main program
def main():
    email_file = 'email.csv'
    template_file = 'email_template.txt'
    email_list = read_email_list(email_file)
    email_template = read_template(template_file)
    create_emails(email_list, email_template)

if __name__ == "__main__":
    main()
# Out:
# ================================================================
# To:      james@gmail.com
# From:    noreply@deals.com
# Subject: Deals!
#
# Hi Darakjy,
#
# We've got some great deals for you. Check our website!
# ================================================================
# ================================================================
# To:      josephine@gmail.com
# From:    noreply@deals.com
# Subject: Deals!
#
# Hi Darakjy,
#
# We've got some great deals for you. Check our website!
# ================================================================
# ================================================================
# To:      art@gmail.com
# From:    noreply@deals.com
# Subject: Deals!
#
# Hi Venere,
#
# We've got some great deals for you. Check our website!
# ================================================================

# %% [markdown]
# ## 10.2 Pig Latin Translator
#
# Create a program that translates English to Pig Latin.
#
# ### Console:
# ```powershell
# Pig Latin Translator
#
# Enter text: Tis but a scratch.
# English:	tis but a scratch
# Pig Latin:	istay utbay away atchscray
#
# Continue? (y/n): y
#
# Enter text: We are the knights who say nee!
# English:	we are the knights who say nee
# Pig Latin:	eway areway ethay ightsknay owhay aysay eenay
#
# Continue? (y/n): n
#
# Bye!
# ```
#
# ### Specifications:
# - Convert the English to lowercase before translating.
# - Remove the following punctuation characters before translating `! , ; : - . ?`
# - Assume that words are separated from each other by a single space.
# - If the word starts with a vowel, just add *way* to the end of the word.
# - If the word starts with a consonant, move all of the consonants that appear before the first vowel to the end of the word, then add *ay* to the end of the word.
#
# ### Note:
# - There are no official rules for Pig Latin. Most people agree on how words that begin with consonants are translated, but there are many different ways to handle words that begin with vowels.

# %%
### CODE HERE ###
def translate():
    sp='!,;:-.?'
    translation = str.maketrans('', '', sp)
    x=(input("Enter Text:")).lower()
    engl=x.translate(translation)
    print("English: "+engl)
    words = engl.split()  
    piglat = [] 
    for word in words:
        if word[0] in 'aeiou':
            pigpart = word + 'way'
        else:
            for i in range(len(word)):
                if word[i] in 'aeiou':
                    pigpart = word[i:] + word[:i] + 'ay'
                    break
        piglat.append(pigpart)
    
    wholepig = ' '.join(piglat)
    print("Pig Latin: " + wholepig)
def main():
    cont='Y'
    while cont=='Y'
        translate()
        cont=input("Continue? Y/N")
    print("Thanks, Bye!")
        
if __name__ == "__main__":
    main()
# Out:
# Enter Text: Ploopheads love to mess with me daily
# English: ploopheads love to mess with me daily
# Pig Latin: oopheadsplay ovelay otay essmay ithway emay ailyday
